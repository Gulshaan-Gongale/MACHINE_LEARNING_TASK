# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dftitan = pd.read_csv("C:/Users/utkar/Downloads/titanic.csv")

# %%
dftitansc
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
dftitan.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True  NaN  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN
# 3  woman       False    C  Southampton   yes  False          NaN
# 4    man        True  NaN  Southampton    no   True          NaN

# %%
dftitan.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN

# %%
dftitan.shape
# Out:
# (891, 16)

# %%
dftitan.size
# Out:
# 14256

# %%
dftitan.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# Unnamed: 15    float64
# dtype: object

# %%
dftitan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(7)
# memory usage: 99.3+ KB

# %%
dftitan.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'Unnamed: 15'],
#       dtype='object')

# %%
dftitan= dftitan[['sex', 'age','fare','class', 'who','embark_town', 'alive', 'alone']]

# %%
x = dftitan.drop(columns = "alive", axis = 1)

# %%
y = dftitan["alive"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.32, random_state = 23)

# %%
x_train.shape, x_test.shape
# Out:
# ((605, 7), (286, 7))

# %%
y_train.shape, y_test.shape
# Out:
# ((605,), (286,))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler, PowerTransformer, OrdinalEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
for i, j in enumerate(x_train.columns):
    print(f'{i}...{j}')
# Out:
# 0...sex
# 1...age
# 2...fare
# 3...class
# 4...who
# 5...embark_town
# 6...alone

# %%
colTrans = ColumnTransformer(transformers=[
 ("ageImputer", SimpleImputer(strategy= "median"),[1]),   
 ("embark_townImputer", SimpleImputer(strategy = "most_frequent"), [5]),  
 ("OneHotEncoder", OneHotEncoder (sparse = False, drop = "First"), [0,4,5,6]),  
 ("ClassOrdinalEncoding", OrdinalEncoder(categories = [['First', "Second", "Third"]]), [3]),   
  ("robustccaler", RobustScaler(), [1,2]),   
  ("yeojohnsonTransformer", PowerTransformer(), [1,2]),
    ], remainder = "passthrough")

# %%
colTrans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ageImputer', SimpleImputer(strategy='median'),
#                                  [1]),
#                                 ('embark_townImputer',
#                                  SimpleImputer(strategy='most_frequent'), [5]),
#                                 ('OneHotEncoder',
#                                  OneHotEncoder(drop='First', sparse=False),
#                                  [0, 4, 5, 6]),
#                                 ('ClassOrdinalEncoding',
#                                  OrdinalEncoder(categories=[['First', 'Second',
#                                                              'Third']]),
#                                  [3]),
#                                 ('robustccaler', RobustScaler(), [1, 2]),
#                                 ('yeojohnsonTransformer', PowerTransformer(),
#                                  [1, 2])])

# %% [markdown]
# ## SKLEARN PIPELINE

# %%
from sklearn import set_config
set_config(display= "diagram")
colTrans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ageImputer', SimpleImputer(strategy='median'),
#                                  [1]),
#                                 ('embark_townImputer',
#                                  SimpleImputer(strategy='most_frequent'), [5]),
#                                 ('OneHotEncoder',
#                                  OneHotEncoder(drop='First', sparse=False),
#                                  [0, 4, 5, 6]),
#                                 ('ClassOrdinalEncoding',
#                                  OrdinalEncoder(categories=[['First', 'Second',
#                                                              'Third']]),
#                                  [3]),
#                                 ('robustccaler', RobustScaler(), [1, 2]),
#                                 ('yeojohnsonTransformer', PowerTransformer(),
#                                  [1, 2])])
